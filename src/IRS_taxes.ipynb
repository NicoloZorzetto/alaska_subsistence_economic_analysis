# %% [markdown]
# # IRS TAXES
# The IRS repository: https://www.irs.gov/downloads/irs-soi?page=17 offers a lot of excel files on regions and communities of the whole US.

# %%
import os
import pandas as pd

# %% [markdown]
# ## File download
#
# With a simple wget script I will download the relevant files for Alaska. I could manually find only 2011 to 2022 files, paying attention to the fact that before 2017 they are XLS files and not XLSX.
#
# I suspect this was the reason for why the dnr file only went back to 2017 - they didn't wget the XLS files, so the XLSX links returned 404 errors.

# %%
import wget

original_files_path = '../../data/irs_tax_data/original'
csv_files_path = '../../data/irs_tax_data/csv'
years = list(range(11, 23))

for year in years:
    if year > 16:
        filetype = 'xlsx'
    else:
        filetype = 'xls'
    
    filename = str(year) + "incyak." + filetype
    target_link = "https://www.irs.gov/pub/irs-soi/" + filename
    
    # wget the target file:
    wget.download(target_link, out = original_files_path)

# %% [markdown]
# ## Convert all to CSV
# Some manipulation for cleanup is needed, but turning all of them into csv's reduses warnings and encoding walkarounds.

# %%
csv_files_path = '../../data/irs_tax_data/modified_csvs'

for file in os.listdir(original_files_path):
    print(file)
    dft = pd.read_excel(os.path.join(original_files_path, file), skiprows=3)
    
    csv_file_name = str(file).split('.')[0] + '.csv'
    dft.to_csv(os.path.join(csv_files_path, csv_file_name))
# Out:
# 18incyak.xlsx
# 14incyak (1).xls
# 15incyak (1).xls
# 16incyak (1).xls
# 17incyak (1).xlsx
# 21incyak (1).xlsx
# 19incyak (1).xlsx
# 20incyak.xlsx
# 15incyak.xls
# 17incyak.xlsx
# 11incyak (1).xls
# 22incyak (1).xlsx
# 19incyak.xlsx
# 16incyak.xls
# 11incyak.xls
# 13incyak (1).xls
# 12incyak (1).xls
# 22incyak.xlsx
# 18incyak (1).xlsx
# 12incyak.xls
# 13incyak.xls
# 21incyak.xlsx
# 14incyak.xls
# 20incyak (1).xlsx

# %% [markdown]
# ## Cleanup files
# The files need some cleanup and streamlining before jointing.

# %%
# Define the column containing the county names and income brackets
def add_area_column(df, col_name):
    df["county"] = df[col_name].where(df[col_name].str.contains("Borough", na=False) | df[col_name].str.contains("Census Area", na=False))
    df["county"] = df["county"].ffill().copy()
    df = df.dropna(subset=[col_name])
    df = df.dropna(subset=['county'])
    
    # now I remove the row where the county is specified under size of adjusted income
    df = df[~(df[col_name].str.contains("Borough", na=False) | df[col_name].str.contains("Census Area", na=False))]

    df.reset_index(drop=True, inplace=True)
        
    
    # save
    return df

# %%
csv_files_path = '../../data/irs_tax_data/modified_csvs'

for file in os.listdir(csv_files_path):
    file_path = os.path.join(csv_files_path, file)
    
    dft = pd.read_csv(file_path)
    dft = add_area_column(dft, 'Size of adjusted gross income by county')
    
    print(file)
    print(dft.columns)
    
    dft = dft.copy()
    dft['year'] = str(20) + file[0:2] # the files have the year as first 2 characters of the filename
        
    # reorder columns
    columns = dft.columns.tolist()
    first_columns = ['year', 'county']
    other_cols = [col for col in columns if col not in first_columns]
    dft = dft[first_columns + other_cols]
    
    dft.to_csv(file_path)
# Out:
# 22incyak.csv
# Index(['Unnamed: 0', 'County \nFIPS \ncode [1]',
#        'Size of adjusted gross income by county', 'Number of returns [2]',
#        'Number of single returns', 'Number of joint returns',
#        'Number of head of household returns',
#        'Number of electronically filed returns',
#        'Number of computer prepared paper returns',
#        'Number with paid preparer's signature',
#        ...
#        'Unnamed: 154', 'Tax due at time of filing [15]', 'Unnamed: 156',
#        'Total overpayments', 'Unnamed: 158', 'Overpayments refunded [16]',
#        'Unnamed: 160', 'Credited to next year's estimated tax', 'Unnamed: 162',
#        'county'],
#       dtype='object', length=165)
# 15incyak (1).csv
# Index(['Unnamed: 0', 'County \nFIPS \ncode [1]',
#        'Size of adjusted gross income by county', 'Number of returns',
#        'Number of single returns', 'Number of joint returns',
#        'Number of head of household returns',
#        'Number with paid preparer's signature', 'Number of exemptions',
#        'Number of dependents',
#        ...
#        'Unnamed: 120', 'Additional Medicare tax', 'Unnamed: 122',
#        'Net investment income tax', 'Unnamed: 124',
#        'Tax due at time of filing [11]', 'Unnamed: 126',
#        'Overpayments refunded [12]', 'Unnamed: 128', 'county'],
#       dtype='object', length=131)
# 11incyak.csv
# Index(['Unnamed: 0', 'County \nFIPS \ncode [1]',
#        'Size of adjusted gross income by county', 'Number of returns',
#        'Number of joint returns', 'Number with paid preparer's signature',
#        'Number of exemptions', 'Number of dependents',
#        'Adjusted gross income (AGI) [2]', 'Salaries and wages in AGI',
#        'Unnamed: 9', 'Taxable interest', 'Unnamed: 11', 'Ordinary dividends',
#        'Unnamed: 13', 'Qualified dividends [3]', 'Unnamed: 15',
#        'Business or profession\nnet income (less loss)', 'Unnamed: 17',
#        'Number of \nfarm returns', 'Net capital gain (less loss) in AGI',
#        'Unnamed: 20',
#        'Taxable individual retirement\narrangement distributions',
#        'Unnamed: 22', 'Pensions and annuities in AGI', 'Unnamed: 24',
#        'Unemployment compensation [4]', 'Unnamed: 26',
#        'Social Security benefits in AGI', 'Unnamed: 28',
#        'Self-employment retirement plans', 'Unnamed: 30',
#        'Total itemized deductions', 'Unnamed: 32',
#        'State and local income taxes', 'Unnamed: 34',
#        'State and local general sales taxes', 'Unnamed: 36',
#        'Real estate taxes', 'Unnamed: 38', 'Taxes paid', 'Unnamed: 40',
#        'Mortgage interest paid', 'Unnamed: 42', 'Contributions', 'Unnamed: 44',
#        'Taxable income', 'Unnamed: 46', 'Total tax credits', 'Unnamed: 48',
#        'Residential energy credit', 'Unnamed: 50', 'Child tax credit',
#        'Unnamed: 52', 'Child and dependent care credit', 'Unnamed: 54',
#        'Additional child tax credit', 'Unnamed: 56',
#        'Earned income credit [5]', 'Unnamed: 58',
#        'Excess earned income \ncredit (refundable) [6]', 'Unnamed: 60',
#        'Alternative minimum tax', 'Unnamed: 62', 'Income tax [7]',
#        'Unnamed: 64', 'Total tax liability [8]', 'Unnamed: 66',
#        'Tax due at time of filing [9]', 'Unnamed: 68',
#        'Overpayments refunded [10]', 'Unnamed: 70', 'county'],
#       dtype='object')
# 21incyak (1).csv
# Index(['Unnamed: 0', 'County \nFIPS \ncode [1]',
#        'Size of adjusted gross income by county', 'Number of returns [2]',
#        'Number of single returns', 'Number of joint returns',
#        'Number of head of household returns',
#        'Number of electronically filed returns',
#        'Number of computer prepared paper returns',
#        'Number with paid preparer's signature',
#        ...
#        'Unnamed: 156', 'Tax due at time of filing [18]', 'Unnamed: 158',
#        'Total overpayments', 'Unnamed: 160', 'Overpayments refunded [19]',
#        'Unnamed: 162', 'Credited to next year's estimated tax', 'Unnamed: 164',
#        'county'],
#       dtype='object', length=167)
# 16incyak (1).csv
# Index(['Unnamed: 0', 'County \nFIPS \ncode [1]',
#        'Size of adjusted gross income by county', 'Number of returns',
#        'Number of single returns', 'Number of joint returns',
#        'Number of head of household returns',
#        'Number with paid preparer's signature', 'Number of exemptions',
#        'Number of dependents',
#        ...
#        'Unnamed: 136', 'Total additional Medicare tax', 'Unnamed: 138',
#        'Net investment income tax', 'Unnamed: 140',
#        'Tax due at time of filing [11]', 'Unnamed: 142',
#        'Overpayments refunded [12]', 'Unnamed: 144', 'county'],
#       dtype='object', length=147)
# 18incyak.csv
# Index(['Unnamed: 0', 'County \nFIPS \ncode [1]',
#        'Size of adjusted gross income by county', 'Number of returns',
#        'Number of single returns', 'Number of joint returns',
#        'Number of head of household returns',
#        'Number of electronically filed returns',
#        'Number of computer prepared paper returns',
#        'Number with paid preparer's signature',
#        ...
#        'Unnamed: 142', 'Tax due at time of filing [12]', 'Unnamed: 144',
#        'Total overpayments', 'Unnamed: 146', 'Overpayments refunded [13]',
#        'Unnamed: 148', 'Credited to next year's estimated tax', 'Unnamed: 150',
#        'county'],
#       dtype='object', length=153)
# 22incyak (1).csv
# Index(['Unnamed: 0', 'County \nFIPS \ncode [1]',
#        'Size of adjusted gross income by county', 'Number of returns [2]',
#        'Number of single returns', 'Number of joint returns',
#        'Number of head of household returns',
#        'Number of electronically filed returns',
#        'Number of computer prepared paper returns',
#        'Number with paid preparer's signature',
#        ...
#        'Unnamed: 154', 'Tax due at time of filing [15]', 'Unnamed: 156',
#        'Total overpayments', 'Unnamed: 158', 'Overpayments refunded [16]',
#        'Unnamed: 160', 'Credited to next year's estimated tax', 'Unnamed: 162',
#        'county'],
#       dtype='object', length=165)
# 20incyak (1).csv
# Index(['Unnamed: 0', 'County \nFIPS \ncode [1]',
#        'Size of adjusted gross income by county', 'Number of returns [2]',
#        'Number of single returns', 'Number of joint returns',
#        'Number of head of household returns',
#        'Number of electronically filed returns',
#        'Number of computer prepared paper returns',
#        'Number with paid preparer's signature',
#        ...
#        'Unnamed: 154', 'Tax due at time of filing [19]', 'Unnamed: 156',
#        'Total overpayments', 'Unnamed: 158', 'Overpayments refunded [20]',
#        'Unnamed: 160', 'Credited to next year's estimated tax', 'Unnamed: 162',
#        'county'],
#       dtype='object', length=165)
# 11incyak (1).csv
# Index(['Unnamed: 0', 'County \nFIPS \ncode [1]',
#        'Size of adjusted gross income by county', 'Number of returns',
#        'Number of joint returns', 'Number with paid preparer's signature',
#        'Number of exemptions', 'Number of dependents',
#        'Adjusted gross income (AGI) [2]', 'Salaries and wages in AGI',
#        'Unnamed: 9', 'Taxable interest', 'Unnamed: 11', 'Ordinary dividends',
#        'Unnamed: 13', 'Qualified dividends [3]', 'Unnamed: 15',
#        'Business or profession\nnet income (less loss)', 'Unnamed: 17',
#        'Number of \nfarm returns', 'Net capital gain (less loss) in AGI',
#        'Unnamed: 20',
#        'Taxable individual retirement\narrangement distributions',
#        'Unnamed: 22', 'Pensions and annuities in AGI', 'Unnamed: 24',
#        'Unemployment compensation [4]', 'Unnamed: 26',
#        'Social Security benefits in AGI', 'Unnamed: 28',
#        'Self-employment retirement plans', 'Unnamed: 30',
#        'Total itemized deductions', 'Unnamed: 32',
#        'State and local income taxes', 'Unnamed: 34',
#        'State and local general sales taxes', 'Unnamed: 36',
#        'Real estate taxes', 'Unnamed: 38', 'Taxes paid', 'Unnamed: 40',
#        'Mortgage interest paid', 'Unnamed: 42', 'Contributions', 'Unnamed: 44',
#        'Taxable income', 'Unnamed: 46', 'Total tax credits', 'Unnamed: 48',
#        'Residential energy credit', 'Unnamed: 50', 'Child tax credit',
#        'Unnamed: 52', 'Child and dependent care credit', 'Unnamed: 54',
#        'Additional child tax credit', 'Unnamed: 56',
#        'Earned income credit [5]', 'Unnamed: 58',
#        'Excess earned income \ncredit (refundable) [6]', 'Unnamed: 60',
#        'Alternative minimum tax', 'Unnamed: 62', 'Income tax [7]',
#        'Unnamed: 64', 'Total tax liability [8]', 'Unnamed: 66',
#        'Tax due at time of filing [9]', 'Unnamed: 68',
#        'Overpayments refunded [10]', 'Unnamed: 70', 'county'],
#       dtype='object')
# 12incyak (1).csv
# Index(['Unnamed: 0', 'County \nFIPS \ncode [1]',
#        'Size of adjusted gross income by county', 'Number of returns',
#        'Number of single returns', 'Number of joint returns',
#        'Number of head of household returns',
#        'Number with paid preparer's signature', 'Number of exemptions',
#        'Number of dependents', 'Adjusted gross income (AGI) [2]',
#        'Salaries and wages in AGI', 'Unnamed: 11', 'Taxable interest',
#        'Unnamed: 13', 'Ordinary dividends', 'Unnamed: 15',
#        'Qualified dividends [3]', 'Unnamed: 17',
#        'Business or profession\nnet income (less loss)', 'Unnamed: 19',
#        'Number of \nfarm returns', 'Net capital gain (less loss) in AGI',
#        'Unnamed: 22',
#        'Taxable individual retirement\narrangement distributions',
#        'Unnamed: 24', 'Pensions and annuities in AGI', 'Unnamed: 26',
#        'Unemployment compensation [4]', 'Unnamed: 28',
#        'Social Security benefits in AGI', 'Unnamed: 30',
#        'Self-employment retirement plans', 'Unnamed: 32',
#        'Total itemized deductions', 'Unnamed: 34', 'Unnamed: 35',
#        'State and local income taxes', 'Unnamed: 37',
#        'State and local general sales taxes', 'Unnamed: 39',
#        'Real estate taxes', 'Unnamed: 41', 'Taxes paid', 'Unnamed: 43',
#        'Mortgage interest paid', 'Unnamed: 45', 'Contributions', 'Unnamed: 47',
#        'Taxable income', 'Unnamed: 49', 'Alternative minimum tax',
#        'Unnamed: 51', 'Total tax credits', 'Unnamed: 53',
#        'Child and dependent care credit', 'Unnamed: 55', 'Child tax credit',
#        'Unnamed: 57', 'Residential energy credit', 'Unnamed: 59',
#        'Earned income credit [5]', 'Unnamed: 61',
#        'Excess earned income \ncredit (refundable) [6]', 'Unnamed: 63',
#        'Additional child tax credit', 'Unnamed: 65', 'Income tax [7]',
#        'Unnamed: 67', 'Total tax liability [8]', 'Unnamed: 69',
#        'Tax due at time of filing [9]', 'Unnamed: 71',
#        'Overpayments refunded [10]', 'Unnamed: 73', 'county'],
#       dtype='object')
# 21incyak.csv
# Index(['Unnamed: 0', 'County \nFIPS \ncode [1]',
#        'Size of adjusted gross income by county', 'Number of returns [2]',
#        'Number of single returns', 'Number of joint returns',
#        'Number of head of household returns',
#        'Number of electronically filed returns',
#        'Number of computer prepared paper returns',
#        'Number with paid preparer's signature',
#        ...
#        'Unnamed: 156', 'Tax due at time of filing [18]', 'Unnamed: 158',
#        'Total overpayments', 'Unnamed: 160', 'Overpayments refunded [19]',
#        'Unnamed: 162', 'Credited to next year's estimated tax', 'Unnamed: 164',
#        'county'],
#       dtype='object', length=167)
# 15incyak.csv
# Index(['Unnamed: 0', 'County \nFIPS \ncode [1]',
#        'Size of adjusted gross income by county', 'Number of returns',
#        'Number of single returns', 'Number of joint returns',
#        'Number of head of household returns',
#        'Number with paid preparer's signature', 'Number of exemptions',
#        'Number of dependents',
#        ...
#        'Unnamed: 120', 'Additional Medicare tax', 'Unnamed: 122',
#        'Net investment income tax', 'Unnamed: 124',
#        'Tax due at time of filing [11]', 'Unnamed: 126',
#        'Overpayments refunded [12]', 'Unnamed: 128', 'county'],
#       dtype='object', length=131)
# 12incyak.csv
# Index(['Unnamed: 0', 'County \nFIPS \ncode [1]',
#        'Size of adjusted gross income by county', 'Number of returns',
#        'Number of single returns', 'Number of joint returns',
#        'Number of head of household returns',
#        'Number with paid preparer's signature', 'Number of exemptions',
#        'Number of dependents', 'Adjusted gross income (AGI) [2]',
#        'Salaries and wages in AGI', 'Unnamed: 11', 'Taxable interest',
#        'Unnamed: 13', 'Ordinary dividends', 'Unnamed: 15',
#        'Qualified dividends [3]', 'Unnamed: 17',
#        'Business or profession\nnet income (less loss)', 'Unnamed: 19',
#        'Number of \nfarm returns', 'Net capital gain (less loss) in AGI',
#        'Unnamed: 22',
#        'Taxable individual retirement\narrangement distributions',
#        'Unnamed: 24', 'Pensions and annuities in AGI', 'Unnamed: 26',
#        'Unemployment compensation [4]', 'Unnamed: 28',
#        'Social Security benefits in AGI', 'Unnamed: 30',
#        'Self-employment retirement plans', 'Unnamed: 32',
#        'Total itemized deductions', 'Unnamed: 34', 'Unnamed: 35',
#        'State and local income taxes', 'Unnamed: 37',
#        'State and local general sales taxes', 'Unnamed: 39',
#        'Real estate taxes', 'Unnamed: 41', 'Taxes paid', 'Unnamed: 43',
#        'Mortgage interest paid', 'Unnamed: 45', 'Contributions', 'Unnamed: 47',
#        'Taxable income', 'Unnamed: 49', 'Alternative minimum tax',
#        'Unnamed: 51', 'Total tax credits', 'Unnamed: 53',
#        'Child and dependent care credit', 'Unnamed: 55', 'Child tax credit',
#        'Unnamed: 57', 'Residential energy credit', 'Unnamed: 59',
#        'Earned income credit [5]', 'Unnamed: 61',
#        'Excess earned income \ncredit (refundable) [6]', 'Unnamed: 63',
#        'Additional child tax credit', 'Unnamed: 65', 'Income tax [7]',
#        'Unnamed: 67', 'Total tax liability [8]', 'Unnamed: 69',
#        'Tax due at time of filing [9]', 'Unnamed: 71',
#        'Overpayments refunded [10]', 'Unnamed: 73', 'county'],
#       dtype='object')
# 17incyak (1).csv
# Index(['Unnamed: 0', 'County \nFIPS \ncode [1]',
#        'Size of adjusted gross income by county', 'Number of returns',
#        'Number of single returns', 'Number of joint returns',
#        'Number of head of household returns',
#        'Number of electronically filed returns',
#        'Number of computer prepared paper returns',
#        'Number with paid preparer's signature',
#        ...
#        'Unnamed: 142', 'Tax due at time of filing [12]', 'Unnamed: 144',
#        'Total overpayments', 'Unnamed: 146', 'Overpayments refunded [13]',
#        'Unnamed: 148', 'Credited to next year's estimated tax', 'Unnamed: 150',
#        'county'],
#       dtype='object', length=153)
# 14incyak (1).csv
# Index(['Unnamed: 0', 'County \nFIPS \ncode [1]',
#        'Size of adjusted gross income by county', 'Number of returns',
#        'Number of single returns', 'Number of joint returns',
#        'Number of head of household returns',
#        'Number with paid preparer's signature', 'Number of exemptions',
#        'Number of dependents',
#        ...
#        'Unnamed: 116', 'Additional Medicare tax', 'Unnamed: 118',
#        'Net investment income tax', 'Unnamed: 120',
#        'Tax due at time of filing [10]', 'Unnamed: 122',
#        'Overpayments refunded [11]', 'Unnamed: 124', 'county'],
#       dtype='object', length=127)
# 16incyak.csv
# Index(['Unnamed: 0', 'County \nFIPS \ncode [1]',
#        'Size of adjusted gross income by county', 'Number of returns',
#        'Number of single returns', 'Number of joint returns',
#        'Number of head of household returns',
#        'Number with paid preparer's signature', 'Number of exemptions',
#        'Number of dependents',
#        ...
#        'Unnamed: 136', 'Total additional Medicare tax', 'Unnamed: 138',
#        'Net investment income tax', 'Unnamed: 140',
#        'Tax due at time of filing [11]', 'Unnamed: 142',
#        'Overpayments refunded [12]', 'Unnamed: 144', 'county'],
#       dtype='object', length=147)
# 13incyak (1).csv
# Index(['Unnamed: 0', 'County \nFIPS \ncode [1]',
#        'Size of adjusted gross income by county', 'Number of returns',
#        'Number of single returns', 'Number of joint returns',
#        'Number of head of household returns',
#        'Number with paid preparer's signature', 'Number of exemptions',
#        'Number of dependents',
#        ...
#        'Unnamed: 103', 'Additional Medicare tax', 'Unnamed: 105',
#        'Net investment income tax', 'Unnamed: 107',
#        'Tax due at time of filing [9]', 'Unnamed: 109',
#        'Overpayments refunded [10]', 'Unnamed: 111', 'county'],
#       dtype='object', length=114)
# 19incyak.csv
# Index(['Unnamed: 0', 'County \nFIPS \ncode [1]',
#        'Size of adjusted gross income by county', 'Number of returns [2]',
#        'Number of single returns', 'Number of joint returns',
#        'Number of head of household returns',
#        'Number of electronically filed returns',
#        'Number of computer prepared paper returns',
#        'Number with paid preparer's signature',
#        ...
#        'Unnamed: 141', 'Tax due at time of filing [15]', 'Unnamed: 143',
#        'Total overpayments', 'Unnamed: 145', 'Overpayments refunded [16]',
#        'Unnamed: 147', 'Credited to next year's estimated tax', 'Unnamed: 149',
#        'county'],
#       dtype='object', length=152)
# 20incyak.csv
# Index(['Unnamed: 0', 'County \nFIPS \ncode [1]',
#        'Size of adjusted gross income by county', 'Number of returns [2]',
#        'Number of single returns', 'Number of joint returns',
#        'Number of head of household returns',
#        'Number of electronically filed returns',
#        'Number of computer prepared paper returns',
#        'Number with paid preparer's signature',
#        ...
#        'Unnamed: 154', 'Tax due at time of filing [19]', 'Unnamed: 156',
#        'Total overpayments', 'Unnamed: 158', 'Overpayments refunded [20]',
#        'Unnamed: 160', 'Credited to next year's estimated tax', 'Unnamed: 162',
#        'county'],
#       dtype='object', length=165)
# 19incyak (1).csv
# Index(['Unnamed: 0', 'County \nFIPS \ncode [1]',
#        'Size of adjusted gross income by county', 'Number of returns [2]',
#        'Number of single returns', 'Number of joint returns',
#        'Number of head of household returns',
#        'Number of electronically filed returns',
#        'Number of computer prepared paper returns',
#        'Number with paid preparer's signature',
#        ...
#        'Unnamed: 141', 'Tax due at time of filing [15]', 'Unnamed: 143',
#        'Total overpayments', 'Unnamed: 145', 'Overpayments refunded [16]',
#        'Unnamed: 147', 'Credited to next year's estimated tax', 'Unnamed: 149',
#        'county'],
#       dtype='object', length=152)
# 18incyak (1).csv
# Index(['Unnamed: 0', 'County \nFIPS \ncode [1]',
#        'Size of adjusted gross income by county', 'Number of returns',
#        'Number of single returns', 'Number of joint returns',
#        'Number of head of household returns',
#        'Number of electronically filed returns',
#        'Number of computer prepared paper returns',
#        'Number with paid preparer's signature',
#        ...
#        'Unnamed: 142', 'Tax due at time of filing [12]', 'Unnamed: 144',
#        'Total overpayments', 'Unnamed: 146', 'Overpayments refunded [13]',
#        'Unnamed: 148', 'Credited to next year's estimated tax', 'Unnamed: 150',
#        'county'],
#       dtype='object', length=153)
# 17incyak.csv
# Index(['Unnamed: 0', 'County \nFIPS \ncode [1]',
#        'Size of adjusted gross income by county', 'Number of returns',
#        'Number of single returns', 'Number of joint returns',
#        'Number of head of household returns',
#        'Number of electronically filed returns',
#        'Number of computer prepared paper returns',
#        'Number with paid preparer's signature',
#        ...
#        'Unnamed: 142', 'Tax due at time of filing [12]', 'Unnamed: 144',
#        'Total overpayments', 'Unnamed: 146', 'Overpayments refunded [13]',
#        'Unnamed: 148', 'Credited to next year's estimated tax', 'Unnamed: 150',
#        'county'],
#       dtype='object', length=153)
# 14incyak.csv
# Index(['Unnamed: 0', 'County \nFIPS \ncode [1]',
#        'Size of adjusted gross income by county', 'Number of returns',
#        'Number of single returns', 'Number of joint returns',
#        'Number of head of household returns',
#        'Number with paid preparer's signature', 'Number of exemptions',
#        'Number of dependents',
#        ...
#        'Unnamed: 116', 'Additional Medicare tax', 'Unnamed: 118',
#        'Net investment income tax', 'Unnamed: 120',
#        'Tax due at time of filing [10]', 'Unnamed: 122',
#        'Overpayments refunded [11]', 'Unnamed: 124', 'county'],
#       dtype='object', length=127)
# 13incyak.csv
# Index(['Unnamed: 0', 'County \nFIPS \ncode [1]',
#        'Size of adjusted gross income by county', 'Number of returns',
#        'Number of single returns', 'Number of joint returns',
#        'Number of head of household returns',
#        'Number with paid preparer's signature', 'Number of exemptions',
#        'Number of dependents',
#        ...
#        'Unnamed: 103', 'Additional Medicare tax', 'Unnamed: 105',
#        'Net investment income tax', 'Unnamed: 107',
#        'Tax due at time of filing [9]', 'Unnamed: 109',
#        'Overpayments refunded [10]', 'Unnamed: 111', 'county'],
#       dtype='object', length=114)

# %% [markdown]
# ## Merge into a single dataframe
# Merge all the individual files from 2011 to 2022 into one dataframe for manipulation and saving

# %%
master = pd.DataFrame()

file_list = os.listdir(csv_files_path)
file_list.sort()

for file in file_list:
    file_path = os.path.join(csv_files_path, file)
    
    dft = pd.read_csv(file_path)
    
    master = pd.concat([master, dft], ignore_index=True)

# %% [markdown]
# ## Merge columns and cleanup
# The IRS named the columns something like 'Earned income credit [5]' with the number changing between years, but not corresponding to them.
#
# This creates multiple columns with NaN for some years but filling up the NaNs for others. I unify them for clarity and simplified later manipulation.

# %%
col_groups = {}
for col in master.columns:
    stripped_name = col.rsplit('[', 1)[0].strip() if '[' in col else col
    col_groups.setdefault(stripped_name, []).append(col)

# Unify if there is no overlap
# columns with different [numbers] represent different years, there should be no overlap
safe_to_unify = []
for base_name, cols in col_groups.items():
    if len(cols) > 1:
        df_slice = master[cols].notna().sum(axis=1)
        if not (df_slice > 1).any():  # Check if safe
            master[base_name] = master[cols].bfill(axis=1).iloc[:, 0]
            master.drop(columns=cols, inplace=True)
            safe_to_unify.append(base_name)

# Original order
essential_cols = ['year', 'county']
ordered_cols = essential_cols + [col for col in master.columns if col not in essential_cols]
master = master[ordered_cols]
# Out:
# /tmp/ipykernel_2301067/876518976.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   master[base_name] = master[cols].bfill(axis=1).iloc[:, 0]
# /tmp/ipykernel_2301067/876518976.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   master[base_name] = master[cols].bfill(axis=1).iloc[:, 0]
# /tmp/ipykernel_2301067/876518976.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   master[base_name] = master[cols].bfill(axis=1).iloc[:, 0]
# /tmp/ipykernel_2301067/876518976.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   master[base_name] = master[cols].bfill(axis=1).iloc[:, 0]
# /tmp/ipykernel_2301067/876518976.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   master[base_name] = master[cols].bfill(axis=1).iloc[:, 0]
# /tmp/ipykernel_2301067/876518976.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   master[base_name] = master[cols].bfill(axis=1).iloc[:, 0]
# /tmp/ipykernel_2301067/876518976.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   master[base_name] = master[cols].bfill(axis=1).iloc[:, 0]
# /tmp/ipykernel_2301067/876518976.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   master[base_name] = master[cols].bfill(axis=1).iloc[:, 0]
# /tmp/ipykernel_2301067/876518976.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   master[base_name] = master[cols].bfill(axis=1).iloc[:, 0]
# /tmp/ipykernel_2301067/876518976.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   master[base_name] = master[cols].bfill(axis=1).iloc[:, 0]
# /tmp/ipykernel_2301067/876518976.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   master[base_name] = master[cols].bfill(axis=1).iloc[:, 0]
# /tmp/ipykernel_2301067/876518976.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   master[base_name] = master[cols].bfill(axis=1).iloc[:, 0]

# %%
[x for x in master.columns.tolist() if 'leave' in x]
# Out:
# ['Qualified sick and family leave credit',
#  'Qualified sick and family leave credit \nfor leave taken beore April 1, 2021',
#  'Qualified sick and family leave credit \nfor leave taken after March 31, 2021']

# %% [markdown]
# ## Compute The tax burden
#
# I define the Tax burdens as such:
# - Total Tax Burden
# \[
# \text{Total Tax Burden} = \frac{\text{Total Tax Liability}}{\text{Adjusted Gross Income (AGI)}}
# \]
# - Federal Tax Burden =
# \[
# \text{Federal Tax Burden} = \frac{\text{Total Tax Liability} - \text{Local Taxes Paid}}{\text{Adjusted Gross Income (AGI)}}
# \]
# - Local Tax Burden =
# \[
# \text{Local Tax Burden} = \frac{\text{State and Local Income Taxes + State and Local General Sales Taxes + Real Estate Taxes + Personal Property Taxes}}{\text{Adjusted Gross Income (AGI)}}
# \]

# %%
import numpy as np

# Combine AGI columns
agi_columns = [col for col in master.columns if "Adjusted gross income (AGI)" in col]
master["AGI_clean"] = master[agi_columns].bfill(axis=1).iloc[:, 0]

# Preserve original NaNs and zeros to avoid misrepresentation
master["AGI_clean"] = np.where(master[agi_columns].isna().all(axis=1), np.nan, master["AGI_clean"])
master["AGI_clean"] = np.where(master[agi_columns].eq(0).all(axis=1), 0, master["AGI_clean"])

# Not all Alaskan Boroughs apply local taxes such as income or personal property taxes
# they thus come up as NaN but it's because they are 0, so I fill them with 0
master["Local_taxes_paid"] = (
    master["State and local income taxes"].fillna(0) +
    master["State and local general sales taxes"].fillna(0) +
    master["Real estate taxes"].fillna(0) +
    master["Personal property taxes"].fillna(0)
)


master["total_tax_burden"] = master["Total tax liability"] / master["AGI_clean"]
master["local_tax_burden"] = master["Local_taxes_paid"] / master["AGI_clean"]
master["federal_tax_burden"] = (
    master["Total tax liability"] - master["Local_taxes_paid"]
) / master["AGI_clean"]

# Set burden to NaN where AGI is zero or NaN to avoid misleading ratios
master.loc[
    master["AGI_clean"].isna() | (master["AGI_clean"] == 0), 
    ["total_tax_burden", "local_tax_burden", "federal_tax_burden"]
] = np.nan

master['child_and_other_dependent_credit'] = master['Child and other dependent credit']
master['social_security_benefits'] = master['Social Security benefits in AGI']
master['sick_and_family_leave_credit'] = master['Qualified sick and family leave credit']
# Out:
# /tmp/ipykernel_2301067/2321295100.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   master["AGI_clean"] = master[agi_columns].bfill(axis=1).iloc[:, 0]
# /tmp/ipykernel_2301067/2321295100.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   master["Local_taxes_paid"] = (
# /tmp/ipykernel_2301067/2321295100.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   master["total_tax_burden"] = master["Total tax liability"] / master["AGI_clean"]
# /tmp/ipykernel_2301067/2321295100.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   master["local_tax_burden"] = master["Local_taxes_paid"] / master["AGI_clean"]
# /tmp/ipykernel_2301067/2321295100.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   master["federal_tax_burden"] = (
# /tmp/ipykernel_2301067/2321295100.py:33: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   master['child_and_other_dependent_credit'] = master['Child and other dependent credit']
# /tmp/ipykernel_2301067/2321295100.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   master['social_security_benefits'] = master['Social Security benefits in AGI']
# /tmp/ipykernel_2301067/2321295100.py:35: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   master['sick_and_family_leave_credit'] = master['Qualified sick and family leave credit']

# %%
master.columns.tolist()
# Out:
# ['year',
#  'county',
#  'Unnamed: 0.1',
#  'Unnamed: 0',
#  'County \nFIPS \ncode [1]',
#  'Size of adjusted gross income by county',
#  'Number of joint returns',
#  "Number with paid preparer's signature",
#  'Number of exemptions',
#  'Number of dependents',
#  'Salaries and wages in AGI',
#  'Unnamed: 9',
#  'Taxable interest',
#  'Unnamed: 11',
#  'Ordinary dividends',
#  'Unnamed: 13',
#  'Unnamed: 15',
#  'Business or profession\nnet income (less loss)',
#  'Unnamed: 17',
#  'Number of \nfarm returns',
#  'Net capital gain (less loss) in AGI',
#  'Unnamed: 20',
#  'Taxable individual retirement\narrangement distributions',
#  'Unnamed: 22',
#  'Pensions and annuities in AGI',
#  'Unnamed: 24',
#  'Unnamed: 26',
#  'Social Security benefits in AGI',
#  'Unnamed: 28',
#  'Self-employment retirement plans',
#  'Unnamed: 30',
#  'Total itemized deductions',
#  'Unnamed: 32',
#  'State and local income taxes',
#  'Unnamed: 34',
#  'State and local general sales taxes',
#  'Unnamed: 36',
#  'Real estate taxes',
#  'Unnamed: 38',
#  'Taxes paid',
#  'Unnamed: 40',
#  'Mortgage interest paid',
#  'Unnamed: 42',
#  'Contributions',
#  'Unnamed: 44',
#  'Taxable income',
#  'Unnamed: 46',
#  'Unnamed: 48',
#  'Residential energy credit',
#  'Unnamed: 50',
#  'Child tax credit',
#  'Unnamed: 52',
#  'Child and dependent care credit',
#  'Unnamed: 54',
#  'Additional child tax credit',
#  'Unnamed: 56',
#  'Unnamed: 58',
#  'Excess earned income \ncredit (refundable) [6]',
#  'Unnamed: 60',
#  'Alternative minimum tax',
#  'Unnamed: 62',
#  'Unnamed: 64',
#  'Unnamed: 66',
#  'Unnamed: 68',
#  'Unnamed: 70',
#  'Number of single returns',
#  'Number of head of household returns',
#  'Unnamed: 19',
#  'Unnamed: 35',
#  'Unnamed: 37',
#  'Unnamed: 39',
#  'Unnamed: 41',
#  'Unnamed: 43',
#  'Unnamed: 45',
#  'Unnamed: 47',
#  'Unnamed: 49',
#  'Unnamed: 51',
#  'Unnamed: 53',
#  'Unnamed: 55',
#  'Unnamed: 57',
#  'Unnamed: 59',
#  'Unnamed: 61',
#  'Unnamed: 63',
#  'Unnamed: 65',
#  'Unnamed: 67',
#  'Unnamed: 69',
#  'Unnamed: 71',
#  'Unnamed: 73',
#  'Total income',
#  'State and local income tax refunds\n',
#  'Unnamed: 21',
#  'Unnamed: 23',
#  'Unnamed: 25',
#  'Unnamed: 27',
#  'Unnamed: 29',
#  'Taxable Social Security benefits',
#  'Partnership/S-corp net income (less loss)',
#  'Total statuory adjustments',
#  'Educator expenses',
#  'Self-employment health insurance deduction',
#  'IRA payments',
#  'Student loan interest deduction',
#  'Tuition and fees deduction',
#  'Domestic production activities deduction',
#  'Income tax before credits',
#  'Unnamed: 75',
#  'Foreign tax credit',
#  'Unnamed: 77',
#  'Unnamed: 79',
#  'Nonrefundable education credit',
#  'Unnamed: 81',
#  'Retirement savings contribution credit',
#  'Unnamed: 83',
#  'Unnamed: 85',
#  'Residential energy tax credit',
#  'Unnamed: 87',
#  'Self-employment tax',
#  'Unnamed: 89',
#  'Total tax payments',
#  'Unnamed: 91',
#  'Unnamed: 93',
#  'Unnamed: 95',
#  'Unnamed: 97',
#  'Unnamed: 99',
#  'Unnamed: 101',
#  'Unnamed: 103',
#  'Additional Medicare tax',
#  'Unnamed: 105',
#  'Net investment income tax',
#  'Unnamed: 107',
#  'Unnamed: 109',
#  'Unnamed: 111',
#  'Unnamed: 10',
#  'Unnamed: 14',
#  'Unnamed: 16',
#  'Unnamed: 18',
#  'Unnamed: 72',
#  'Unnamed: 74',
#  'Unnamed: 76',
#  'Excess advance premium tax credit repayment',
#  'Unnamed: 78',
#  'Unnamed: 80',
#  'Unnamed: 82',
#  'Unnamed: 84',
#  'Unnamed: 86',
#  'Unnamed: 88',
#  'Unnamed: 90',
#  'Unnamed: 92',
#  'Unnamed: 94',
#  'Total premium tax credit',
#  'Unnamed: 96',
#  'Advance premium tax credit',
#  'Unnamed: 98',
#  'Health care individual responsibility payment',
#  'Unnamed: 100',
#  'Unnamed: 102',
#  'Unnamed: 104',
#  'Unnamed: 106',
#  'Unnamed: 108',
#  'Unnamed: 110',
#  'Net premium tax credit',
#  'Unnamed: 112',
#  'Unnamed: 114',
#  'Unnamed: 116',
#  'Unnamed: 118',
#  'Unnamed: 120',
#  'Unnamed: 122',
#  'Unnamed: 124',
#  'Unnamed: 12',
#  'Number of refund anticipation loan returns',
#  'Unnamed: 126',
#  'Unnamed: 128',
#  'Self-employed (Keogh) retirement plans',
#  'Self-employed health insurance deduction',
#  'Individual retirement arrangement payments',
#  'Total medical and dental \nexpenses deduction',
#  'Personal property taxes',
#  'Total taxes paid',
#  'Home mortgage interest paid ',
#  'Home mortgage interest paid \nfrom personal seller',
#  'Deductible points',
#  'Qualified mortgage insurance premiums',
#  'Investment interest paid',
#  'Total charitable contributions',
#  'Net limited miscellaneous deduction',
#  'Other non-limited \nmiscellaneous deduction',
#  'Excess advance \npremium tax credit repayment',
#  'Retirement savings contributions credit',
#  'Health care individual \nresponsibility payment',
#  'Unnamed: 130',
#  'Unnamed: 132',
#  'Unnamed: 134',
#  'Unnamed: 136',
#  'Total additional Medicare tax',
#  'Unnamed: 138',
#  'Unnamed: 140',
#  'Unnamed: 142',
#  'Unnamed: 144',
#  'Number of electronically filed returns',
#  'Number of computer prepared paper returns',
#  'Number of returns with direct deposit',
#  'Number of dependent exemptions',
#  'Home mortgage interest paid \nto personal seller',
#  'Gambling loss deduction \nand other non-limited \nmiscellaneous deduction',
#  'Total overpayments',
#  'Unnamed: 146',
#  'Unnamed: 148',
#  "Credited to next year's estimated tax",
#  'Unnamed: 150',
#  'Taxable IRA, pensions and annuities',
#  'Total standard deduction',
#  'Basic standard deduction',
#  'Additional standard deduction',
#  'Limited state and local taxes paid',
#  'Other non-limited miscellaneous deduction',
#  'Qualified business income deduction\n',
#  'Child and other dependent credit',
#  'Income tax after credits',
#  'Unnamed: 31',
#  'Unnamed: 33',
#  'Taxable individual retirement arrangements distributions',
#  'Taxable pensions and annuities',
#  'Unnamed: 113',
#  'Unnamed: 115',
#  'Unnamed: 117',
#  'Unnamed: 119',
#  'Unnamed: 121',
#  'Unnamed: 123',
#  'Unnamed: 125',
#  'Unnamed: 127',
#  'Unnamed: 129',
#  'Unnamed: 131',
#  'Unnamed: 133',
#  'Unnamed: 135',
#  'Unnamed: 137',
#  'Unnamed: 139',
#  'Unnamed: 141',
#  'Unnamed: 143',
#  'Unnamed: 145',
#  'Unnamed: 147',
#  'Unnamed: 149',
#  'Number of returns with virtual \ncurrency indicator',
#  'Charitable contributions \nif took standard deduction',
#  'Qualified sick and family leave credit',
#  'Recovery rebate credit [14]',
#  'Economic impact payment\nfirst round [15, 16]',
#  'Economic impact payment\nsecond round [15, 17]',
#  'Unnamed: 152',
#  'Unnamed: 154',
#  'Unnamed: 156',
#  'Unnamed: 158',
#  'Unnamed: 160',
#  'Unnamed: 162',
#  'Nonrefundable child care credit',
#  'Nonrefundable child and \nother dependent tax credit',
#  'Refundable child tax credit or \nadditional child tax credit',
#  'Qualified sick and family leave credit \nfor leave taken beore April 1, 2021',
#  'Refundable child and \ndependent care credit',
#  'Qualified sick and family leave credit \nfor leave taken after March 31, 2021',
#  'Economic impact payment\nthird round [15, 16]',
#  'Unnamed: 164',
#  'Tax-exempt interest [8]',
#  'Total rental and royalty \nnet income (less loss)',
#  'Earned income credit \nwith no qualifying children',
#  'Earned income credit \nwith one qualifying children',
#  'Earned income credit \nwith two qualifying children',
#  'Earned income credit \nwith three or more qualifying children',
#  'Adjusted gross income (AGI)',
#  'Qualified dividends',
#  'Earned income credit',
#  'Income tax',
#  'Total tax liability',
#  'Tax due at time of filing',
#  'Overpayments refunded',
#  'Excess earned income credit (refundable)',
#  'Number of volunteer prepared returns',
#  'Number of elderly returns',
#  'Excess earned income credit \n(refundable)',
#  'Number of \nindividuals',
#  'AGI_clean',
#  'Local_taxes_paid',
#  'total_tax_burden',
#  'local_tax_burden',
#  'federal_tax_burden',
#  'child_and_other_dependent_credit',
#  'social_security_benefits',
#  'sick_and_family_leave_credit']

# %% [markdown]
# ## Compute inequality measure (GINI)
# Given the division of the population into income brakets, I compute the GINI coefficient as measure for inequality:
# \[
# G = 1 - \sum_{i=1}^{n}(X_i - X_{i-1})(Y_i + Y_{i-1})
# \]
#
# Where:
#
# - \(X_i\) is the cumulative share of the population up to the income bracket \(i\).
# - \(Y_i\) is the cumulative share of income up to the income bracket \(i\).

# %%
# compute the total number of returns filling NaNs as zeroes
master["Number_of_returns"] = (
    master["Number of single returns"].fillna(0) +
    master["Number of joint returns"].fillna(0) +
    master["Number of head of household returns"].fillna(0)
)

# Explicitly map income brackets to midpoints
income_bracket_to_midpoint = {
    "Under $1": 500,
    "$1 under $10,000": 5000,
    "$10,000 under $25,000": 17500,
    "$25,000 under $50,000": 37500,
    "$50,000 under $75,000": 62500,
    "$75,000 under $100,000": 87500,
    "$100,000 under $200,000": 150000,
    "$200,000 or more": 250000
}
# Out:
# /tmp/ipykernel_2301067/1056130966.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   master["Number_of_returns"] = (

# %%
def gini_coefficient(incomes, weights):    
    # Sort incomes and weights
    sorted_indices = np.argsort(incomes)
    incomes = incomes[sorted_indices]
    weights = weights[sorted_indices]

    cum_weights = np.cumsum(weights)
    cum_income = np.cumsum(incomes * weights)

    # Normalize cumulative sums
    cum_weights_normalized = cum_weights / cum_weights[-1]
    cum_income_normalized = cum_income / cum_income[-1]

    # Calculate Gini using trapezoidal approximation
    gini = 1 - 2 * np.trapz(cum_income_normalized, cum_weights_normalized)
    return gini

# Compute Gini by group
def compute_gini_by_group(df):
    bracket_names = df["Size of adjusted gross income by county"].values
    counts = df["Number_of_returns"].values
    
    # Map income brackets to midpoints using the explicit map created above
    midpoints = np.array([income_bracket_to_midpoint.get(bracket, np.nan) for bracket in bracket_names])

    # Drop rows with NaN midpoints if any
    valid = ~np.isnan(midpoints)
    midpoints = midpoints[valid]
    counts = counts[valid]

    if counts.sum() == 0:
        return np.nan
    
    return gini_coefficient(midpoints, counts)

# Apply the function
gini_df = master.groupby(['county', 'year'], group_keys=False).apply(compute_gini_by_group).reset_index()
gini_df.columns = ['county', 'year', 'Gini']

# Merge Gini back to master
master = master.merge(gini_df, on=['county', 'year'], how='left')

# %% [markdown]
# # Save as single file in the custom directory

# %%
# Save to the custom data directory
csv_files_path = '../../data/irs_tax_data/modified_csvs'

custom_data_directory = '../../data/custom_data'
irs_taxes_merged_path = os.path.join(custom_data_directory, 'irs_taxes_custom.csv')

master.to_csv(irs_taxes_merged_path)
